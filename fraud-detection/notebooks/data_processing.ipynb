# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import os

import sys
sys.path.append('../src')
#from model import 
from preprocessing import split_data, preprocess_fraud

# %%
df = pd.read_csv('../data/fraud.zip')
df.head(3)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
#
# [3 rows x 31 columns]

# %%
df.describe().T.head()
# Out:
#          count          mean           std        min           25%  \
# Time  284807.0  9.481386e+04  47488.145955   0.000000  54201.500000
# V1    284807.0  1.168375e-15      1.958696 -56.407510     -0.920373
# V2    284807.0  3.416908e-16      1.651309 -72.715728     -0.598550
# V3    284807.0 -1.379537e-15      1.516255 -48.325589     -0.890365
# V4    284807.0  2.074095e-15      1.415869  -5.683171     -0.848640
#
#                50%            75%            max
# Time  84692.000000  139320.500000  172792.000000
# V1        0.018109       1.315642       2.454930
# V2        0.065486       0.803724      22.057729
# V3        0.179846       1.027196       9.382558
# V4       -0.019847       0.743341      16.875344

# %%
dd = preprocess_fraud(df)
display(dd['clean'].head(3))
display(dd['scaled'].head(3))
display(dd['pca'].head(3))
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
#
# [3 rows x 31 columns]
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# ...

# %%
# Save dataframes
save_paths = ['../data/clean-fraud.pkl', '../data/scaled-fraud.pkl', '../data/pca-fraud.pkl']
files = [dd['clean'], dd['scaled'], dd['pca']]
for sp, file in zip(save_paths, files):
    if os.path.isfile(sp):
        print(f'File Already Exists -- {sp}')
        pass
    else:
        pd.to_pickle(file, sp)
        print(f"File Saved --> {sp}")
# Out:
# File Saved --> ../data/clean-fraud.pkl
# File Saved --> ../data/scaled-fraud.pkl
# File Saved --> ../data/pca-fraud.pkl

# %%
class_grp = df[df['Amount'] > 0].copy().groupby(['Class'])['Class'].count()
dfgrp = pd.DataFrame(class_grp)
display(dfgrp)

print(f'Percent of Fraud: {round(float((dfgrp.iloc[1] / dfgrp.iloc[0])*100), 2)}%')
# Out:
#         Class
# Class
# 0      282517
# 1         465
# Percent of Fraud: 0.16%

# %%
dfc = df.copy()[df['Amount'] > 0]

splits = split_data(dfc)

# %%
for i in splits[2:]:
    print(f"Total Transactions = {i.shape[0]}")
    print(f"Fraudulent transactions = {sum(i)} -- {round((sum(i)/i.shape[0])*100, 2)}%")
# Out:
# Total Transactions = 226385
# Fraudulent transactions = 368 -- 0.16%
# Total Transactions = 56597
# Fraudulent transactions = 97 -- 0.17%

# %%
# TODO: resampling to increase class size of fraud
